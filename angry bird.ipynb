# %%
import numpy as np
import matplotlib.pyplot as plt
import math

v=np.random.random(2)
a=v[0]*100
b=v[1]*50
plt.plot(a,b,'o')
plt.figure(figsize=(10,10))

# %%
t=np.linspace(0, 10, 100, endpoint=True)
v0=float(input("Enter intial velocity."))
theta=float(input("Enter the intial angle.")) #degree
x=v0*math.cos(theta)*t
y=v0*math.sin(theta)*t-1/2*9.8*t**2
plt.plot(x,y)
plt.plot(a,b,'o')
plt.xlim(0,100)
plt.ylim(0,50)
# Out:
# Enter intial velocity.33
# Enter the intial angle.45
# (0, 50)
