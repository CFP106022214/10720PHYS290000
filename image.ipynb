# %%
# %matplotlib inline
import matplotlib.image as mpimg

im=mpimg.imread('P1120107.JPG')
import matplotlib.pyplot as plt
plt.imshow(im)

# %%
print(im.shape)
# Out:
# (794, 1059, 3)

# %%
r_im=im[:,:,0]
plt.imshow(r_im)

# %%
g_im=im[:,:,1]
plt.imshow(g_im)

# %%
b_im=im[:,:,2]
plt.imshow(b_im)

# %%
plt.hist(b_im.ravel())
# Out:
# (array([  5910.,  10516.,  11773.,   9382.,   7750.,   6040.,   7096.,
#         203169., 434150., 145060.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <a list of 10 Patch objects>)

# %%
import numpy as np
print(np.mean(b_im))
print(np.median(b_im))
# Out:
# 206.13587862700186
# 213.0
